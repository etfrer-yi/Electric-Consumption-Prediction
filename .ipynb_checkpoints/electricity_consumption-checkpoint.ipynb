# %%
# https://stackoverflow.com/questions/48302810/whats-the-difference-between-hidden-and-output-in-pytorch-lstm

import numpy as np
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
print(torch.cuda.is_available())
import os
np.random.seed(0)
# Out:
# False

# %%
# Define the folder path
folder_path = 'data'

csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
relative_paths = [os.path.join(folder_path, file) for file in csv_files]

dfs = []

for csv in relative_paths:
    dfs.append(pd.read_csv(csv))

# %%
aep_hourly_csv = dfs[0]
time_series_data = aep_hourly_csv['AEP_MW']

def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Create sequences
seq_length = 100
X, y = create_sequences(time_series_data, seq_length)

# Split into training and test sets
train_size = int(0.9 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Convert to tensors
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(-1)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(-1)
y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(-1)
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(-1)

# %%
def print_output_hook(module, _input, output):
    pass
#     print(f"Input shape: {_input[0].shape}")
#     print(f"Output shape: {output}")
#     print("-" * 50)

def first_iter_print_batch(epoch, i, inputs, targets):
    if i == 0 and epoch == 0:
        print(f"inputs shape: {inputs.shape}")
        print("inputs:")
        print(inputs)
        print("\n")
        print(f"targets shape: {targets.shape}")
        print("targets:")
        print(targets)

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        self.register_hooks()
    
    def register_hooks(self):
        for name, module in self.named_modules():
            if module != self:
                module.register_forward_hook(print_output_hook)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# Initialize the model
input_size = 1
hidden_size = 50
output_size = 1
model = RNN(input_size, hidden_size, output_size)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

class Dataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        return self.X[index], self.y[index]

train_dataset = Dataset(X_train, y_train)
test_dataset = Dataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def save_checkpoint(model, optimizer, epoch, loss, checkpoint_path):
    """
    Saves a checkpoint with the model state, optimizer state, epoch, and loss.
    """
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'epoch': epoch,
        'loss': loss
    }
    torch.save(checkpoint, checkpoint_path)
    print(f"Checkpoint saved to {checkpoint_path}")

def load_checkpoint(checkpoint_path, model, optimizer):
    """
    Loads a checkpoint and returns the model, optimizer, epoch, and loss.
    """
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    start_epoch = checkpoint['epoch'] + 1
    return model, optimizer, start_epoch, checkpoint['loss']

    
def train_loop_per_epoch(train_loader, model, optimizer, epoch, checkpoint_path="checkpoint.pth"):
    epoch_loss = 0
    for i, (inputs, targets) in enumerate(train_loader):
        # first_iter_print_batch(epoch, i, inputs, targets)
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    epoch_loss /= (len(train_loader) - seq_length)
    
    if not os.path.exists(checkpoint_path) or epoch_loss < torch.load(checkpoint_path)['loss']:
        save_checkpoint(model, optimizer, epoch, epoch_loss, checkpoint_path)
    print(f'Epoch {epoch+1}, Loss: {epoch_loss}')

def train_over_epochs(start_epoch, num_epochs, train_loader, model, optimizer, checkpoint_path="checkpoint.pth"):
    if os.path.exists(checkpoint_path):
        model, optimizer, start_epoch, _ = load_checkpoint(checkpoint_path, model, optimizer)
    for epoch in range(start_epoch, num_epochs):
        train_loop_per_epoch(train_loader, model, optimizer, epoch)
    
num_epochs = 100
train_over_epochs(0, num_epochs, train_loader, model, optimizer)
# Out:
# Checkpoint saved to checkpoint.pth
# Epoch 3, Loss: 253684066.43772674
# Checkpoint saved to checkpoint.pth
# Epoch 4, Loss: 252352324.4159613
# Checkpoint saved to checkpoint.pth
# Epoch 5, Loss: 251024185.40266022
# Checkpoint saved to checkpoint.pth
# Epoch 6, Loss: 249699907.54050785
# Checkpoint saved to checkpoint.pth
# Epoch 7, Loss: 248378785.13663846
# Checkpoint saved to checkpoint.pth
# Epoch 8, Loss: 247062067.51632407
# Checkpoint saved to checkpoint.pth
# Epoch 9, Loss: 245748084.11124545
# Checkpoint saved to checkpoint.pth
# Epoch 10, Loss: 244438501.38331318
# Checkpoint saved to checkpoint.pth
# Epoch 11, Loss: 243131955.17775092
# Checkpoint saved to checkpoint.pth
# Epoch 12, Loss: 241828637.9879081
# Checkpoint saved to checkpoint.pth
# Epoch 13, Loss: 240530058.72793227
# Checkpoint saved to checkpoint.pth
# Epoch 14, Loss: 239234902.6215236
# Checkpoint saved to checkpoint.pth
# Epoch 15, Loss: 237942714.1185006
# Checkpoint saved to checkpoint.pth
# Epoch 16, Loss: 236654319.84038693
# Checkpoint saved to checkpoint.pth
# Epoch 17, Loss: 235369582.070133
# Checkpoint saved to checkpoint.pth
# Epoch 18, Loss: 234088521.24788392
# Checkpoint saved to checkpoint.pth
# Epoch 19, Loss: 232810926.90205562
# Checkpoint saved to checkpoint.pth
# Epoch 20, Loss: 231537310.78113663
# Checkpoint saved to checkpoint.pth
# Epoch 21, Loss: 230267028.14026603
# Checkpoint saved to checkpoint.pth
# Epoch 22, Loss: 229000003.67110035
# Checkpoint saved to checkpoint.pth
# Epoch 23, Loss: 227736799.70012093
# Checkpoint saved to checkpoint.pth
# Epoch 24, Loss: 226477420.75453445
# Checkpoint saved to checkpoint.pth
# Epoch 25, Loss: 225221624.7738815
# Checkpoint saved to checkpoint.pth
# Epoch 26, Loss: 223969402.04594922
# Checkpoint saved to checkpoint.pth
# Epoch 27, Loss: 222720918.36517534
# Checkpoint saved to checkpoint.pth
# Epoch 28, Loss: 221476311.87424424
# Checkpoint saved to checkpoint.pth
# Epoch 29, Loss: 220234378.56348246
# Checkpoint saved to checkpoint.pth
# Epoch 30, Loss: 218996782.15719467
# Checkpoint saved to checkpoint.pth
# Epoch 31, Loss: 217762326.88754535
# Checkpoint saved to checkpoint.pth
# Epoch 32, Loss: 216531858.52478838
# Checkpoint saved to checkpoint.pth
# Epoch 33, Loss: 215305282.85368803
# Checkpoint saved to checkpoint.pth
# Epoch 34, Loss: 214081753.54292625
# Checkpoint saved to checkpoint.pth
# Epoch 35, Loss: 212862152.27085853
# Checkpoint saved to checkpoint.pth
# Epoch 36, Loss: 211646050.1523579
# Checkpoint saved to checkpoint.pth
# Epoch 37, Loss: 210433236.64812577
# Checkpoint saved to checkpoint.pth
# Epoch 38, Loss: 209224188.04353082
# Checkpoint saved to checkpoint.pth
# Epoch 39, Loss: 208019338.38452238
# Checkpoint saved to checkpoint.pth
# Epoch 40, Loss: 206817192.91414753
# Checkpoint saved to checkpoint.pth
# Epoch 41, Loss: 205619521.7363966
# Checkpoint saved to checkpoint.pth
# Epoch 42, Loss: 204425405.53808948
# Checkpoint saved to checkpoint.pth
# Epoch 43, Loss: 203233963.03748488
# Checkpoint saved to checkpoint.pth
# Epoch 44, Loss: 202046521.76058042
# Checkpoint saved to checkpoint.pth
# Epoch 45, Loss: 200863098.85368803
# Checkpoint saved to checkpoint.pth
# Epoch 46, Loss: 199683421.86215237
# Checkpoint saved to checkpoint.pth
# Epoch 47, Loss: 198506611.61789602
# Checkpoint saved to checkpoint.pth
# Epoch 48, Loss: 197333927.02781138
# Checkpoint saved to checkpoint.pth
# Epoch 49, Loss: 196164922.41354293
# Checkpoint saved to checkpoint.pth
# Epoch 50, Loss: 194999257.54292625
# Checkpoint saved to checkpoint.pth
# Epoch 51, Loss: 193836863.64691657
# Checkpoint saved to checkpoint.pth
# Epoch 52, Loss: 192678746.21039903
# Checkpoint saved to checkpoint.pth
# Epoch 53, Loss: 191524143.5018138
# Checkpoint saved to checkpoint.pth
# Epoch 54, Loss: 190372954.9891173
# Checkpoint saved to checkpoint.pth
# Epoch 55, Loss: 189225136.32889965
# Checkpoint saved to checkpoint.pth
# Epoch 56, Loss: 188080997.93470374
# Checkpoint saved to checkpoint.pth
# Epoch 57, Loss: 186940948.39661428
# Checkpoint saved to checkpoint.pth
# Epoch 58, Loss: 185804426.09915358
# Checkpoint saved to checkpoint.pth
# Epoch 59, Loss: 184670771.74848852
# Checkpoint saved to checkpoint.pth
# Epoch 60, Loss: 183540789.35429263
# Checkpoint saved to checkpoint.pth
# Epoch 61, Loss: 182415145.4897219
# Checkpoint saved to checkpoint.pth
# Epoch 62, Loss: 181292790.92623943
# Checkpoint saved to checkpoint.pth
# Epoch 63, Loss: 180173775.40024185
# Checkpoint saved to checkpoint.pth
# Epoch 64, Loss: 179059072.63603386

# %%
# Evaluate the model
model.eval()
with torch.no_grad():
    total_loss = 0
    for inputs, targets in test_loader:
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        total_loss += loss.item()
    avg_loss = total_loss / len(test_loader)
    print(f'Test Loss: {avg_loss:.4f}')
